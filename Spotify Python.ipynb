# %%
pip install spotipy
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.3 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials
import pandas as pd

# %%
client_credentials_manager = SpotifyClientCredentials(client_id="7a43e2470f5e4d138afe05589a01fc6f",client_secret="c376c7726e98446aacdf6ab28c56fc8a")

# %%
sp = spotipy.Spotify(client_credentials_manager = client_credentials_manager)

# %%
playlist_link = "https://open.spotify.com/playlist/0Ozuve71TWqmFQ5XQGzUO9"

# %%
playlist_URI=playlist_link.split("/")[-1].split('?')[0]

# %%
data = sp.playlist_tracks(playlist_URI)

# %%
data['items'][0]['track']['album']
# Out:
# {'available_markets': ['AR',
#   'AU',
#   'AT',
#   'BE',
#   'BO',
#   'BR',
#   'BG',
#   'CA',
#   'CL',
#   'CO',
#   'CR',
#   'CY',
#   'CZ',
#   'DK',
#   'DO',
#   'DE',
#   'EC',
#   'EE',
#   'SV',
#   'FI',
#   'FR',
#   'GR',
#   'GT',
#   'HN',
#   'HK',
#   'HU',
#   'IS',
#   'IE',
#   'IT',
#   'LV',
#   'LT',
#   'LU',
#   'MY',
#   'MT',
#   'MX',
#   'NL',
#   'NZ',
#   'NI',
#   'NO',
#   'PA',
#   'PY',
#   'PE',
#   'PH',
#   'PL',
#   'PT',
#   'SG',
#   'SK',
#   'ES',
#   'SE',
#   'CH',
#   'TW',
#   'TR',
#   'UY',
#   'US',
#   'GB',
#   'AD',
#   'LI',
#   'MC',
#   'ID',
#   'JP',
#   'TH',
#   'VN',
#   'RO',
#   'IL',
#   'ZA',
#   'SA',
#   'AE',
#   'BH',
#   'QA',
#   'OM',
#   'KW',
#   'EG',
#   'MA',
#   'DZ',
#   'TN',
#   'LB',
#   'JO',
#   'PS',
#   'IN',
#   'BY',
#   'KZ',
#   'MD',
#   'UA',
#   'AL',
#   'BA',
#   'HR',
#   'ME',
#   'MK',
#   'RS',
#   'SI',
#   'KR',
#   'BD',
#   'PK',
#   'LK',
#   'GH',
#   'KE',
#   'NG',
# ...

# %%
data['items'][0]['track']['album']['id']
# Out:
# '3Ha8CM9px7D2fn25K4ijl6'

# %%
data['items'][0]['track']['album']['name']
# Out:
# 'OK Jaanu (Original Motion Picture Soundtrack)'

# %%
data['items'][0]['track']['album']['release_date']
# Out:
# '2017-01-04'

# %%
data['items'][0]['track']['album']['total_tracks']
# Out:
# 8

# %%
data['items'][0]['track']['album']['external_urls']['spotify']
# Out:
# 'https://open.spotify.com/album/3Ha8CM9px7D2fn25K4ijl6'

# %%
album_list = []
for row in data['items'] :
    album_id = row['track']['album']['id']
    album_name = row['track']['album']['name']
    album_release_date = row['track']['album']['release_date']
    album_total_tracks = row['track']['album']['total_tracks']
    album_url = row['track']['album']['external_urls']['spotify']
    album_elements = {'album_id' : album_id, 'name':album_name, 'release-date':album_release_date,'total_tracks': album_total_tracks,'url':album_url}
    album_list.append(album_elements)

# %%
album_list
# Out:
# [{'album_id': '3Ha8CM9px7D2fn25K4ijl6',
#   'name': 'OK Jaanu (Original Motion Picture Soundtrack)',
#   'release-date': '2017-01-04',
#   'total_tracks': 8,
#   'url': 'https://open.spotify.com/album/3Ha8CM9px7D2fn25K4ijl6'},
#  {'album_id': '5sMovvp4SR99laIsnzfwJE',
#   'name': 'A.R. Rahman All Time Favourites',
#   'release-date': '2022-06-16',
#   'total_tracks': 16,
#   'url': 'https://open.spotify.com/album/5sMovvp4SR99laIsnzfwJE'},
#  {'album_id': '6cqYgHZhpSKKb7xUuxJCAr',
#   'name': 'Raayan (Original Motion Picture Soundtrack)',
#   'release-date': '2024-07-06',
#   'total_tracks': 5,
#   'url': 'https://open.spotify.com/album/6cqYgHZhpSKKb7xUuxJCAr'},
#  {'album_id': '6cqYgHZhpSKKb7xUuxJCAr',
#   'name': 'Raayan (Original Motion Picture Soundtrack)',
#   'release-date': '2024-07-06',
#   'total_tracks': 5,
#   'url': 'https://open.spotify.com/album/6cqYgHZhpSKKb7xUuxJCAr'},
#  {'album_id': '6kWI9GDPhMhaGNo80Q1XT5',
#   'name': 'Guru (Original Motion Picture Soundtrack)',
# ...

# %%
data['items'][1]['track']['artists']
# Out:
# [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1mYsTxnqsietFxj1OgoGbG'},
#   'href': 'https://api.spotify.com/v1/artists/1mYsTxnqsietFxj1OgoGbG',
#   'id': '1mYsTxnqsietFxj1OgoGbG',
#   'name': 'A.R. Rahman',
#   'type': 'artist',
#   'uri': 'spotify:artist:1mYsTxnqsietFxj1OgoGbG'},
#  {'external_urls': {'spotify': 'https://open.spotify.com/artist/281Vp9LDrWkHMHQzfQHWCt'},
#   'href': 'https://api.spotify.com/v1/artists/281Vp9LDrWkHMHQzfQHWCt',
#   'id': '281Vp9LDrWkHMHQzfQHWCt',
#   'name': 'Rashid Ali',
#   'type': 'artist',
#   'uri': 'spotify:artist:281Vp9LDrWkHMHQzfQHWCt'}]

# %%
artist_list = [] 
for row in data['items']:
    for key ,value in row.items(): 
        if key == 'track':
            for artist in value['artists']:
                artist_dict = {'artist_id': artist['id'], 'artist_name': artist['name'], 'external_url': artist['href']}
                artist_list.append(artist_dict)

# %%
artist_list
# Out:
# [{'artist_id': '1mYsTxnqsietFxj1OgoGbG',
#   'artist_name': 'A.R. Rahman',
#   'external_url': 'https://api.spotify.com/v1/artists/1mYsTxnqsietFxj1OgoGbG'},
#  {'artist_id': '4YRxDV8wJFPHPTeXepOstw',
#   'artist_name': 'Arijit Singh',
#   'external_url': 'https://api.spotify.com/v1/artists/4YRxDV8wJFPHPTeXepOstw'},
#  {'artist_id': '1mYsTxnqsietFxj1OgoGbG',
#   'artist_name': 'A.R. Rahman',
#   'external_url': 'https://api.spotify.com/v1/artists/1mYsTxnqsietFxj1OgoGbG'},
#  {'artist_id': '281Vp9LDrWkHMHQzfQHWCt',
#   'artist_name': 'Rashid Ali',
#   'external_url': 'https://api.spotify.com/v1/artists/281Vp9LDrWkHMHQzfQHWCt'},
#  {'artist_id': '1mYsTxnqsietFxj1OgoGbG',
#   'artist_name': 'A.R. Rahman',
#   'external_url': 'https://api.spotify.com/v1/artists/1mYsTxnqsietFxj1OgoGbG'},
#  {'artist_id': '2F3KtUVtrt2GLjcl6pB4cz',
#   'artist_name': 'Dhanush',
#   'external_url': 'https://api.spotify.com/v1/artists/2F3KtUVtrt2GLjcl6pB4cz'},
#  {'artist_id': '5FVBduYaeVBb6JIghza7v6',
# ...

# %%
song_list = []

for row in data['items']:
    song_id = row['track']['id']
    song_name = row['track']['name']
    song_duration = row['track']['duration_ms']
    song_url = row['track']['external_urls']['spotify']
    song_popularity = row['track']['popularity']
    song_added = row['added_at']
    album_id = row['track']['album']['id']
    artist_id = row['track']['album']['artists'][0]['id']

    song_element = {
        'song_id': song_id,
        'song_name': song_name,
        'song_popularity': song_popularity,
        'duration_ms': song_duration,
        'url': song_url,
        'popularity' : song_popularity,
        'song_added' : song_added,
        'album_id' : album_id,
        'artist_id': artist_id
    }

    song_list.append(song_element)

# %%
song_list
# Out:
# [{'song_id': '6bdpj89aYEBjhpsenXAsmO',
#   'song_name': 'Enna Sona',
#   'song_popularity': 74,
#   'duration_ms': 213646,
#   'url': 'https://open.spotify.com/track/6bdpj89aYEBjhpsenXAsmO',
#   'popularity': 74,
#   'song_added': '2026-01-05T19:37:22Z',
#   'album_id': '3Ha8CM9px7D2fn25K4ijl6',
#   'artist_id': '1mYsTxnqsietFxj1OgoGbG'},
#  {'song_id': '0IBb4UQMbRfoVdHJpmrRn4',
#   'song_name': 'Kabhi Kabhi Aditi (From "Jaane Tu... Ya Jaane Na")',
#   'song_popularity': 40,
#   'duration_ms': 218836,
#   'url': 'https://open.spotify.com/track/0IBb4UQMbRfoVdHJpmrRn4',
#   'popularity': 40,
#   'song_added': '2026-01-05T19:37:22Z',
#   'album_id': '5sMovvp4SR99laIsnzfwJE',
#   'artist_id': '0LyfQWJT6nXafLPZqxe9Of'},
#  {'song_id': '1JKjaWrHqLRu47B9o5qpay',
#   'song_name': 'Adangaatha Asuran',
#   'song_popularity': 54,
#   'duration_ms': 249027,
#   'url': 'https://open.spotify.com/track/1JKjaWrHqLRu47B9o5qpay',
#   'popularity': 54,
#   'song_added': '2026-01-05T19:37:22Z',
# ...

# %%
album_df = pd.DataFrame.from_dict(album_list)

# %%
album_df.head()
# Out:
#                  album_id                                           name  \
# 0  3Ha8CM9px7D2fn25K4ijl6  OK Jaanu (Original Motion Picture Soundtrack)
# 1  5sMovvp4SR99laIsnzfwJE                A.R. Rahman All Time Favourites
# 2  6cqYgHZhpSKKb7xUuxJCAr    Raayan (Original Motion Picture Soundtrack)
# 3  6cqYgHZhpSKKb7xUuxJCAr    Raayan (Original Motion Picture Soundtrack)
# 4  6kWI9GDPhMhaGNo80Q1XT5      Guru (Original Motion Picture Soundtrack)
#
#   release-date  total_tracks  \
# 0   2017-01-04             8
# 1   2022-06-16            16
# 2   2024-07-06             5
# 3   2024-07-06             5
# 4   2006-09-11             7
#
#                                                  url
# 0  https://open.spotify.com/album/3Ha8CM9px7D2fn2...
# 1  https://open.spotify.com/album/5sMovvp4SR99laI...
# 2  https://open.spotify.com/album/6cqYgHZhpSKKb7x...
# 3  https://open.spotify.com/album/6cqYgHZhpSKKb7x...
# 4  https://open.spotify.com/album/6kWI9GDPhMhaGNo...

# %%
album_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   album_id      5 non-null      object
#  1   name          5 non-null      object
#  2   release-date  5 non-null      object
#  3   total_tracks  5 non-null      int64
#  4   url           5 non-null      object
# dtypes: int64(1), object(4)
# memory usage: 332.0+ bytes

# %%
album_df = album_df.drop_duplicates(subset=['album_id'])

# %%
artist_df = pd.DataFrame.from_dict(artist_list)

# %%
artist_df
# Out:
#                  artist_id         artist_name  \
# 0   1mYsTxnqsietFxj1OgoGbG         A.R. Rahman
# 1   4YRxDV8wJFPHPTeXepOstw        Arijit Singh
# 2   1mYsTxnqsietFxj1OgoGbG         A.R. Rahman
# 3   281Vp9LDrWkHMHQzfQHWCt          Rashid Ali
# 4   1mYsTxnqsietFxj1OgoGbG         A.R. Rahman
# 5   2F3KtUVtrt2GLjcl6pB4cz             Dhanush
# 6   5FVBduYaeVBb6JIghza7v6  Santhosh Narayanan
# 7   1rdQOMFFtoskDXXUVjiGo9        Shweta Mohan
# 8   0T487EE91kx2O8oGPO8Krh         Gana Kadhar
# 9   1mYsTxnqsietFxj1OgoGbG         A.R. Rahman
# 10  5UJ2sHO2ELrgW6aXeRLTQQ            Chinmayi
# 11  3v8isPrc8btWVMF3bnOIcj        Murtuza Khan
# 12  2gTPBFjo3M9rvMSZWTk9nT          Qadir Khan
#
#                                          external_url
# 0   https://api.spotify.com/v1/artists/1mYsTxnqsie...
# 1   https://api.spotify.com/v1/artists/4YRxDV8wJFP...
# 2   https://api.spotify.com/v1/artists/1mYsTxnqsie...
# 3   https://api.spotify.com/v1/artists/281Vp9LDrWk...
# ...

# %%
artist_df = artist_df.drop_duplicates(subset=['artist_id'])

# %%
song_df = pd.DataFrame.from_dict(song_list)

# %%
song_df.head()
# Out:
#                   song_id                                          song_name  \
# 0  6bdpj89aYEBjhpsenXAsmO                                          Enna Sona
# 1  0IBb4UQMbRfoVdHJpmrRn4  Kabhi Kabhi Aditi (From "Jaane Tu... Ya Jaane ...
# 2  1JKjaWrHqLRu47B9o5qpay                                  Adangaatha Asuran
# 3  1l4CYsCwvTRRAW2cmsVZ36                                       Water Packet
# 4  4FeczSomVWVyU4FW7xDeAI                                          Tere Bina
#
#    song_popularity  duration_ms  \
# 0               74       213646
# 1               40       218836
# 2               54       249027
# 3               48       246002
# 4               81       309640
#
#                                                  url  popularity  \
# 0  https://open.spotify.com/track/6bdpj89aYEBjhps...          74
# 1  https://open.spotify.com/track/0IBb4UQMbRfoVdH...          40
# 2  https://open.spotify.com/track/1JKjaWrHqLRu47B...          54
# ...

# %%
artist_df.head()
# Out:
#                 artist_id         artist_name  \
# 0  1mYsTxnqsietFxj1OgoGbG         A.R. Rahman
# 1  4YRxDV8wJFPHPTeXepOstw        Arijit Singh
# 3  281Vp9LDrWkHMHQzfQHWCt          Rashid Ali
# 5  2F3KtUVtrt2GLjcl6pB4cz             Dhanush
# 6  5FVBduYaeVBb6JIghza7v6  Santhosh Narayanan
#
#                                         external_url
# 0  https://api.spotify.com/v1/artists/1mYsTxnqsie...
# 1  https://api.spotify.com/v1/artists/4YRxDV8wJFP...
# 3  https://api.spotify.com/v1/artists/281Vp9LDrWk...
# 5  https://api.spotify.com/v1/artists/2F3KtUVtrt2...
# 6  https://api.spotify.com/v1/artists/5FVBduYaeVB...

# %%
album_df.head()
# Out:
#                  album_id                                           name  \
# 0  3Ha8CM9px7D2fn25K4ijl6  OK Jaanu (Original Motion Picture Soundtrack)
# 1  5sMovvp4SR99laIsnzfwJE                A.R. Rahman All Time Favourites
# 2  6cqYgHZhpSKKb7xUuxJCAr    Raayan (Original Motion Picture Soundtrack)
# 4  6kWI9GDPhMhaGNo80Q1XT5      Guru (Original Motion Picture Soundtrack)
#
#   release-date  total_tracks  \
# 0   2017-01-04             8
# 1   2022-06-16            16
# 2   2024-07-06             5
# 4   2006-09-11             7
#
#                                                  url
# 0  https://open.spotify.com/album/3Ha8CM9px7D2fn2...
# 1  https://open.spotify.com/album/5sMovvp4SR99laI...
# 2  https://open.spotify.com/album/6cqYgHZhpSKKb7x...
# 4  https://open.spotify.com/album/6kWI9GDPhMhaGNo...

# %%
album_df['release-date'] = pd.to_datetime(album_df['release-date'])

# %%
album_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 4 entries, 0 to 4
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   album_id      4 non-null      object
#  1   name          4 non-null      object
#  2   release-date  4 non-null      datetime64[ns]
#  3   total_tracks  4 non-null      int64
#  4   url           4 non-null      object
# dtypes: datetime64[ns](1), int64(1), object(3)
# memory usage: 192.0+ bytes

# %%
song_df['song_added'] = pd.to_datetime(song_df['song_added'])

# %%
song_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 9 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   song_id          5 non-null      object
#  1   song_name        5 non-null      object
#  2   song_popularity  5 non-null      int64
#  3   duration_ms      5 non-null      int64
#  4   url              5 non-null      object
#  5   popularity       5 non-null      int64
#  6   song_added       5 non-null      datetime64[ns, UTC]
#  7   album_id         5 non-null      object
#  8   artist_id        5 non-null      object
# dtypes: datetime64[ns, UTC](1), int64(3), object(5)
# memory usage: 492.0+ bytes
